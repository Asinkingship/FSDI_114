# %% [markdown]
# # Doubly Linked Lists
#
# A Doubly Linked list is also known as a bi-directional list. It is comprised of `nodes` that keep and maintain a reference to the `previous`
# node in the collection, as well as the `next` node in the collection

# %%
# F scratch implementation of Doubly Linked Lists

class DoublyLinkedList:
    class __Node:
        def __init__(self, data):
            self.prev = None
            self.next = None
            self.data = data

    def __init__(self):
        self.head = None
        self.tail = None

    def append(self, value):
        new_node = self.__Node(value)
        if not self.head:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            new_node.prev = self.tail
            self.tail = new_node
    def insert(self, index, value):
        #this inserts a new node with the given value Before the target index
        #Note: there are some madditional considerations for the combinations of "index" and the state of our lists.
        pass
        
    def remove(self, value):
        # this removes the *first* instance of the given value
        # start at the head
        #current = self.head
        # start a loop to look for the given value
        # if the value to be removed is the head then make the next node the new head
        #if the value to be removed is the tail then update the pevious as the new tail
        # if the 
        pass

    def index(self, value):
        # this returns the *first* index of the given value

        # start at the head
        # the current = self.head
        # index = 0
            #while current 
                # if the current data equals the value
                    # return the index
                # if the current doesnt equal the value 
                    # move to next node in the list
                #If value is not found upon completion of the loop -> return an error
        pass

    def __get__(self, index):
        #this method allows you to use squarte bracket notation to retreive a value at the target index (IE dll[5])
        pass

    def __set__(self, index, value):
        #this method allows you to use squarte bracket notation to insert a node into the list (IE dll[5] ="A")
        pass

    def __len__(self):
        # this will return the number of nodes in our list
        count = 0
        current = self.head
        while current:
            count += 1
            current = current.next
        return count

    def __bool__(self):
        #this will help evaluate our list with "if" and "if not"
        return self.head !=None

    def inverted(self):
        # this method allows us to print(or return a string) of our list, but in inverted order
        pass 

    def __str__(self):
        out = "["
        current = self.head
        if current:
            out += "%s" % repr(current.data)
            while current.next:
                current = current.next
                out += ", %s" % repr(current.data)
        out += "]"
        return out

# %%
# Comparing python3 lists to out DLL implementation
pylist = []
dll = DoublyLinkedList()

print("Empty python list: %s" % pylist)
print("Empty DLL: %s" % dll)

pylist.append(0)
dll.append(0)
print("Python list with one element: %s" % pylist)
print("DLL with one element: %s" % dll)

pylist.append(1)
dll.append(1)
print("Python list with more than one element: %s" % pylist)
print("DLL with more than one element: %s" % dll)

# displaying the length of our lists
print("displaying the length of our python list: %s" % len(pylist))
print("the length of out DLL: %s" % len(dll))
# Out:
# Empty python list: []
# Empty DLL: []
# Python list with one element: [0]
# DLL with one element: [0]
# Python list with more than one element: [0, 1]
# DLL with more than one element: [0, 1]
# displaying the length of our python list: 2
# the length of out DLL: 2
