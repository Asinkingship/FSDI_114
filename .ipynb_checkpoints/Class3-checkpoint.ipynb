# %% [markdown]
# # Linked lists
#
# In todays class, we're going to introduce the two varieties of linked lists:
# 1. Singly  Linked Lists (uni-directional)
# 2. Doubly Linked Lists  (uni-directional)

# %%
# How python does it

help([])
# Out:
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
# ...

# %%
mylist = []
#printing an empty list:
print(mylist)

mylist.append(0)
#printing a list with ezactly one element:
print(mylist)

mylist.append(1)
#Printing a list with more tham one element:
print(mylist)
# Out:
# []
# [0]
# [0, 1]

# %%
class SinglyLinkedList:
    class __Node:
        def __init__(self, data):
            self.data = data
            self.next = None

    def __init__(self):
        self.head = None
        self.tail = None

    def append(self, value):
        new_node = self.__Node(value)
        if not self.head:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node

    def insert(self, index, value):
        #create new_node with the incoming value
        #if there is no head:
        #  make it so that mynew node is now the head node
        #  also make it so my new_node is the tail node
        #Otherwise:
        #  if the index i receive is 0:
        #     replace the head reference to point at my new node
        #  otherwise:
        #     initialize a variable called current which starts by pointing at the head node
        #     initialize a variable called previous which starts by pointing at none
        #     loop while these two conditions are not met
        #              condition 1: there must be a next node to loop
        #              condition 2: i have not yet found the target index( this is so long as count does not equal index)
        #     these are the instruction that happen everytime i loop
        #          1. i update previous to point to the same thing current is pointing to
        #          1. i update current to point to the next node in my list
        #          1. i update count such that count is now equal to count plus 1
        #  when i exit the loop one of two conditions can be met:
        #      if count is equal to index:    ( this means i found the target index)
        #          update the previous nodes next reference to point to the new node
        #          UPDATE NEW NODE'S  next reference to point to currnt
        #       otherwise:
        #           execute the append operastion
    
    
    
    def remove(self, value):
        current = self.head
        previous = None
        #while current
            # if the current search = value
                #if previous,  previous becomes current
                #if previous is none then new head becomes current next
                #if its the tail then it becames previous??
            #return true if value is found
            #return false if value is not found
                

    
    def __str__(self):
        out = "["
        current = self.head
        if current:
            out += "%s" % repr(current.data)
            while current.next:
                current = current.next
                out += ", %s" % repr(current.data)
        out += "]"
        return out

# %%
sll = SinglyLinkedList()

print(sll)

sll.append(0)
print(sll)

sll.append(1)
print(sll)
# Out:
# []
# [0]
# [0, 1]

# %%
#With python lists
newlist = []

#inserting at index 1000 on empty list
newlist.insert(1000, "A")

print(newlist)

newlist.insert(0, "Z")
print(newlist)

#when the provided indexis exactly equal to 0, we are replacing the new node with insert

#inserting anywhere between head and tail
newlist.insert(1, 1)
print(newlist)
# Out:
# ['A']
# ['Z', 'A']
# ['Z', 1, 'A']
